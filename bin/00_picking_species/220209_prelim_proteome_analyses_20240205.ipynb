# %%
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import shutil

project_dir = 'H:/My Drive/career/proj/sprg'

# %%
##
## Read in data
##

# need to scrape all 'Task2-SearchTask/AllPeptides.psmtsv' results from all species subdirectories. 
refseq_dir = os.path.join(project_dir, "data/refseq"); print(refseq_dir)
refseq_df = pd.DataFrame()
for subdir, dirs, files in os.walk(refseq_dir):
    print(subdir); print(dirs); print(files)
    for file in files:
        #print(os.path.join(subdir, file))
        if file.endswith("AllPeptides.psmtsv"):
            #print(os.path.join(subdir, file))
            df = pd.read_table(os.path.join(subdir, file))
            #print(df.head())
            refseq_df = refseq_df.append(df)
            
# merge an annotation file with the results file for prettier labeling
annotations_df = pd.read_csv(os.path.join(project_dir, "data/refseq/annotations.csv"))
refseq_df = pd.merge(refseq_df, annotations_df, on='File Name')
refseq_df.head()
# Out:
# H:/My Drive/career/proj/sprg\data/refseq
# H:/My Drive/career/proj/sprg\data/refseq
# ['apple', 'tomato', 'trout', 'peach', 'rice', 'human', 'cow']
# ['annotations.csv', 'desktop.ini']
# H:/My Drive/career/proj/sprg\data/refseq\apple
# ['Task1-CalibrateTask', 'Task Settings', 'Task2-SearchTask']
# ['allResults.txt', 'desktop.ini']
# H:/My Drive/career/proj/sprg\data/refseq\apple\Task1-CalibrateTask
# []
# ['20211105_CAAppleDDA_01-calib.toml', 'results.txt', 'AutoGeneratedManuscriptProse.txt', 'desktop.ini']
# H:/My Drive/career/proj/sprg\data/refseq\apple\Task Settings
# []
# ['Task1-CalibrateTaskconfig.toml', 'Task2-SearchTaskconfig.toml', 'desktop.ini']
# H:/My Drive/career/proj/sprg\data/refseq\apple\Task2-SearchTask
# []
# ['model.zip', 'AllPSMs.psmtsv', 'AllPSMs_FormattedForPercolator.tab', 'AllQuantifiedProteinGroups.tsv', '20211105_CAAppleDDA_01-calib.mzID', 'AllQuantifiedPeaks.tsv', 'AllQuantifiedPeptides.tsv', 'AllPeptides.psmtsv', 'results.txt', 'AutoGeneratedManuscriptProse.txt', 'Task2-SearchTask - Shortcut.lnk', 'desktop.ini']
# C:\Users\linds\AppData\Local\Temp\ipykernel_8644\2770121835.py:14: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_table(os.path.join(subdir, file))
# C:\Users\linds\AppData\Local\Temp\ipykernel_8644\2770121835.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   refseq_df = refseq_df.append(df)
# H:/My Drive/career/proj/sprg\data/refseq\tomato
# ['Task1-CalibrateTask', 'Task Settings', 'Task2-SearchTask']
# ['allResults.txt', 'desktop.ini']
# H:/My Drive/career/proj/sprg\data/refseq\tomato\Task1-CalibrateTask
# []
# ['20211105_CATomatoDDA_01-calib (1).mzML', '20211105_CATomatoDDA_01-calib.mzML', '20211105_CATomatoDDA_01-calib (1).toml', '20211105_CATomatoDDA_01-calib.toml', 'results (1).txt', 'results.txt', 'AutoGeneratedManuscriptProse (1).txt', 'AutoGeneratedManuscriptProse.txt', 'desktop.ini']
# H:/My Drive/career/proj/sprg\data/refseq\tomato\Task Settings
# []
# ['Task1-CalibrateTaskconfig (1).toml', 'Task1-CalibrateTaskconfig.toml', 'Task2-SearchTaskconfig (1).toml', 'Task2-SearchTaskconfig.toml', 'desktop.ini']
# H:/My Drive/career/proj/sprg\data/refseq\tomato\Task2-SearchTask
# []
# ['model (1).zip', 'model.zip', 'AllPSMs (1).psmtsv', 'AllPSMs.psmtsv', 'AllPSMs_FormattedForPercolator (1).tab', 'AllPSMs_FormattedForPercolator.tab', 'AllQuantifiedProteinGroups (1).tsv', 'AllQuantifiedProteinGroups.tsv', '20211105_CATomatoDDA_01-calib (1).mzID', '20211105_CATomatoDDA_01-calib.mzID', 'AllQuantifiedPeaks (1).tsv', 'AllQuantifiedPeaks.tsv', 'AllQuantifiedPeptides (1).tsv', 'AllQuantifiedPeptides.tsv', 'AllPeptides (2).psmtsv', 'AllPeptides.psmtsv', 'results (1).txt', 'results.txt', 'AutoGeneratedManuscriptProse (1).txt', 'AutoGeneratedManuscriptProse.txt', 'desktop.ini']
# C:\Users\linds\AppData\Local\Temp\ipykernel_8644\2770121835.py:14: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_table(os.path.join(subdir, file))
# C:\Users\linds\AppData\Local\Temp\ipykernel_8644\2770121835.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   refseq_df = refseq_df.append(df)
# H:/My Drive/career/proj/sprg\data/refseq\trout
# ['Task1-CalibrateTask (1)', 'Task1-CalibrateTask', 'Task Settings (1)', 'Task Settings', 'Task2-SearchTask (1)', 'Task2-SearchTask']
# ['allResults (1).txt', 'allResults.txt', 'desktop.ini']
# H:/My Drive/career/proj/sprg\data/refseq\trout\Task1-CalibrateTask (1)
# []
# ['desktop.ini']
# H:/My Drive/career/proj/sprg\data/refseq\trout\Task1-CalibrateTask
# []
# ['20211105_CAFishAQDDA_01-calib.mzML', '20211105_CAFishAQDDA_01-calib.toml', 'results.txt', 'AutoGeneratedManuscriptProse.txt', 'desktop.ini']
# H:/My Drive/career/proj/sprg\data/refseq\trout\Task Settings (1)
# []
# ['desktop.ini']
# H:/My Drive/career/proj/sprg\data/refseq\trout\Task Settings
# []
# ['Task1-CalibrateTaskconfig.toml', 'Task2-SearchTaskconfig.toml', 'desktop.ini']
# H:/My Drive/career/proj/sprg\data/refseq\trout\Task2-SearchTask (1)
# []
# ['model.zip', 'AllPSMs.psmtsv', 'AllPSMs_FormattedForPercolator.tab', 'AllQuantifiedProteinGroups.tsv', '20211105_CAFishAQDDA_01-calib.mzID', 'AllQuantifiedPeaks.tsv', 'AllQuantifiedPeptides.tsv', 'AllPeptides.psmtsv', 'results.txt', 'AutoGeneratedManuscriptProse.txt', 'desktop.ini']
# C:\Users\linds\AppData\Local\Temp\ipykernel_8644\2770121835.py:14: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_table(os.path.join(subdir, file))
# C:\Users\linds\AppData\Local\Temp\ipykernel_8644\2770121835.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   refseq_df = refseq_df.append(df)
# H:/My Drive/career/proj/sprg\data/refseq\trout\Task2-SearchTask
# []
# ['desktop.ini']
# H:/My Drive/career/proj/sprg\data/refseq\peach
# ['Task2-SearchTask', 'Task1-CalibrateTask', 'Task Settings']
# ['allResults.txt', 'desktop.ini']
# H:/My Drive/career/proj/sprg\data/refseq\peach\Task2-SearchTask
# []
# ['results.txt', 'AutoGeneratedManuscriptProse.txt', 'model.zip', 'AllQuantifiedProteinGroups.tsv', 'AllQuantifiedPeptides.tsv', 'AllQuantifiedPeaks.tsv', 'model (1).zip', 'AllPSMs.psmtsv', 'AllPSMs_FormattedForPercolator.tab', 'AllQuantifiedProteinGroups (1).tsv', '20211105_CAPeachDDA_01-calib.mzID', 'AllQuantifiedPeaks (1).tsv', 'AllQuantifiedPeptides (1).tsv', 'AllPeptides.psmtsv', 'results (1).txt', 'AutoGeneratedManuscriptProse (1).txt', 'desktop.ini']
# C:\Users\linds\AppData\Local\Temp\ipykernel_8644\2770121835.py:14: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_table(os.path.join(subdir, file))
# C:\Users\linds\AppData\Local\Temp\ipykernel_8644\2770121835.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   refseq_df = refseq_df.append(df)
# H:/My Drive/career/proj/sprg\data/refseq\peach\Task1-CalibrateTask
# []
# ['results.txt', 'AutoGeneratedManuscriptProse.txt', '20211105_CAPeachDDA_01-calib.toml', '20211105_CAPeachDDA_01-calib.mzML', '20211105_CAPeachDDA_01-calib (2).toml', '20211105_CAPeachDDA_01-calib (1).toml', 'results (2).txt', 'results (1).txt', 'AutoGeneratedManuscriptProse (2).txt', 'AutoGeneratedManuscriptProse (1).txt', 'desktop.ini']
# H:/My Drive/career/proj/sprg\data/refseq\peach\Task Settings
# []
# ['Task2-SearchTaskconfig.toml', 'Task1-CalibrateTaskconfig.toml', 'Task1-CalibrateTaskconfig (2).toml', 'Task1-CalibrateTaskconfig (1).toml', 'Task2-SearchTaskconfig (2).toml', 'Task2-SearchTaskconfig (1).toml', 'desktop.ini']
# H:/My Drive/career/proj/sprg\data/refseq\rice
# ['Task1-CalibrateTask', 'Task Settings', 'Task2-SearchTask']
# ['allResults.txt', 'desktop.ini']
# H:/My Drive/career/proj/sprg\data/refseq\rice\Task1-CalibrateTask
# []
# ['AutoGeneratedManuscriptProse.txt', 'results.txt', '20211105_CARiceDDA_01-calib.toml', '20211105_CARiceDDA_01-calib.mzML', '20211105_CARiceDDA_01-calib (2).mzML', '20211105_CARiceDDA_01-calib (1).mzML', '20211105_CARiceDDA_01-calib (2).toml', '20211105_CARiceDDA_01-calib (1).toml', 'results (2).txt', 'results (1).txt', 'AutoGeneratedManuscriptProse (2).txt', 'AutoGeneratedManuscriptProse (1).txt', 'desktop.ini']
# H:/My Drive/career/proj/sprg\data/refseq\rice\Task Settings
# []
# ['Task2-SearchTaskconfig.toml', 'Task1-CalibrateTaskconfig.toml', 'Task1-CalibrateTaskconfig (2).toml', 'Task1-CalibrateTaskconfig (1).toml', 'Task2-SearchTaskconfig (2).toml', 'Task2-SearchTaskconfig (1).toml', 'desktop.ini']
# H:/My Drive/career/proj/sprg\data/refseq\rice\Task2-SearchTask
# []
# ['AllPSMs.psmtsv', 'AllPeptides.psmtsv', '20211105_CARiceDDA_01-calib.mzID', 'AllQuantifiedPeptides.tsv', 'AllQuantifiedPeaks.tsv', 'AllPSMs_FormattedForPercolator.tab', 'AllQuantifiedProteinGroups.tsv', 'AutoGeneratedManuscriptProse.txt', 'model (1).zip', 'model.zip', 'AllPSMs (2).psmtsv', 'AllPSMs (1).psmtsv', 'AllPSMs_FormattedForPercolator (2).tab', 'AllPSMs_FormattedForPercolator (1).tab', 'AllQuantifiedProteinGroups (2).tsv', 'AllQuantifiedProteinGroups (1).tsv', '20211105_CARiceDDA_01-calib (2).mzID', '20211105_CARiceDDA_01-calib (1).mzID', 'AllQuantifiedPeaks (2).tsv', 'AllQuantifiedPeaks (1).tsv', 'AllQuantifiedPeptides (2).tsv', 'AllQuantifiedPeptides (1).tsv', 'results (1).txt', 'results.txt', 'AutoGeneratedManuscriptProse (2).txt', 'AutoGeneratedManuscriptProse (1).txt', 'desktop.ini']
# C:\Users\linds\AppData\Local\Temp\ipykernel_8644\2770121835.py:14: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_table(os.path.join(subdir, file))
# C:\Users\linds\AppData\Local\Temp\ipykernel_8644\2770121835.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   refseq_df = refseq_df.append(df)
# H:/My Drive/career/proj/sprg\data/refseq\human
# ['Task1-CalibrateTask', 'Task Settings', 'Task2-SearchTask']
# ['allResults.txt', 'desktop.ini']
# H:/My Drive/career/proj/sprg\data/refseq\human\Task1-CalibrateTask
# []
# ['20211105_CAHumanLiverDDADiluted_01-calib.toml', 'results.txt', 'AutoGeneratedManuscriptProse.txt', 'desktop.ini']
# H:/My Drive/career/proj/sprg\data/refseq\human\Task Settings
# []
# ['Task1-CalibrateTaskconfig.toml', 'Task2-SearchTaskconfig.toml', 'desktop.ini']
# H:/My Drive/career/proj/sprg\data/refseq\human\Task2-SearchTask
# []
# ['model.zip', 'AllPSMs.psmtsv', 'AllPSMs_FormattedForPercolator.tab', 'AllQuantifiedProteinGroups.tsv', 'AllQuantifiedPeaks.tsv', 'AllQuantifiedPeptides.tsv', 'AllPeptides.psmtsv', 'results.txt', 'AutoGeneratedManuscriptProse.txt', 'desktop.ini']
# C:\Users\linds\AppData\Local\Temp\ipykernel_8644\2770121835.py:14: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_table(os.path.join(subdir, file))
# C:\Users\linds\AppData\Local\Temp\ipykernel_8644\2770121835.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   refseq_df = refseq_df.append(df)
# H:/My Drive/career/proj/sprg\data/refseq\cow
# ['Task1-CalibrateTask', 'Task Settings', 'Task2-SearchTask']
# ['allResults.txt', 'desktop.ini']
# H:/My Drive/career/proj/sprg\data/refseq\cow\Task1-CalibrateTask
# []
# ['20211105_CACowLiverDDA_01-calib.toml', 'results.txt', 'AutoGeneratedManuscriptProse.txt', 'desktop.ini']
# H:/My Drive/career/proj/sprg\data/refseq\cow\Task Settings
# []
# ['Task1-CalibrateTaskconfig.toml', 'Task2-SearchTaskconfig.toml', 'desktop.ini']
# H:/My Drive/career/proj/sprg\data/refseq\cow\Task2-SearchTask
# []
# ['model.zip', 'AllPSMs.psmtsv', 'AllPSMs_FormattedForPercolator.tab', 'AllQuantifiedProteinGroups.tsv', 'AllQuantifiedPeaks.tsv', 'AllQuantifiedPeptides.tsv', 'AllPeptides.psmtsv', 'results.txt', 'AutoGeneratedManuscriptProse.txt', 'desktop.ini']
# C:\Users\linds\AppData\Local\Temp\ipykernel_8644\2770121835.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   refseq_df = refseq_df.append(df)
#                       File Name  Scan Number  Scan Retention Time  \
# 0  20211105_CAAppleDDA_01-calib        37173             33.26919
# 1  20211105_CAAppleDDA_01-calib        77049             65.62497
# 2  20211105_CAAppleDDA_01-calib        84758             77.22049
# 3  20211105_CAAppleDDA_01-calib        58145             48.91731
# 4  20211105_CAAppleDDA_01-calib        59451             49.96893
#
#    Num Experimental Peaks  Total Ion Current  Precursor Scan Number  \
# 0                   200.0       173969.71747                  37161
# 1                   180.0       621423.49811                  76979
# 2                   200.0       301256.32605                  84726
# 3                   200.0       252261.56372                  58101
# 4                   200.0       562062.11438                  59388
#
#    Precursor Charge  Precursor MZ  Precursor Mass   Score  ...  \
# 0               3.0     941.10059      2820.27993  24.316  ...
# 1               2.0     882.51740      1763.02026  24.201  ...
# 2               3.0     951.79106      2852.35136  23.417  ...
# 3               2.0     964.43216      1926.84976  23.318  ...
# 4               3.0     843.39440      2527.16136  23.137  ...
#
#    Improvement Possible  Cumulative Target Cumulative Decoy QValue  \
# 0                                        1                0    0.0
# 1                                        2                0    0.0
# 2                                        3                0    0.0
# 3                                        4                0    0.0
# 4                                        5                0    0.0
#
#   Cumulative Target Notch Cumulative Decoy Notch  QValue Notch           PEP  \
# 0                       1                      0           0.0  4.768372e-07
# 1                       2                      0           0.0  1.132488e-06
# 2                       3                      0           0.0  0.000000e+00
# 3                       4                      0           0.0  1.311302e-06
# 4                       5                      0           0.0  0.000000e+00
#
#   PEP_QValue Species
# 0        0.0   Apple
# 1        0.0   Apple
# 2        0.0   Apple
# 3        0.0   Apple
# 4        0.0   Apple
#
# [5 rows x 57 columns]

# %%
list(refseq_df)
# Out:
# ['File Name',
#  'Scan Number',
#  'Scan Retention Time',
#  'Num Experimental Peaks',
#  'Total Ion Current',
#  'Precursor Scan Number',
#  'Precursor Charge',
#  'Precursor MZ',
#  'Precursor Mass',
#  'Score',
#  'Delta Score',
#  'Notch',
#  'Base Sequence',
#  'Full Sequence',
#  'Essential Sequence',
#  'Ambiguity Level',
#  'PSM Count (unambiguous, <0.01 q-value)',
#  'Mods',
#  'Mods Chemical Formulas',
#  'Mods Combined Chemical Formula',
#  'Num Variable Mods',
#  'Missed Cleavages',
#  'Peptide Monoisotopic Mass',
#  'Mass Diff (Da)',
#  'Mass Diff (ppm)',
#  'Protein Accession',
#  'Protein Name',
#  'Gene Name',
#  'Organism Name',
#  'Identified Sequence Variations',
#  'Splice Sites',
#  'Contaminant',
#  'Decoy',
#  'Peptide Description',
#  'Start and End Residues In Protein',
#  'Previous Amino Acid',
#  'Next Amino Acid',
#  'Theoreticals Searched',
#  'Decoy/Contaminant/Target',
#  'Matched Ion Series',
#  'Matched Ion Mass-To-Charge Ratios',
#  'Matched Ion Mass Diff (Da)',
#  'Matched Ion Mass Diff (Ppm)',
#  'Matched Ion Intensities',
#  'Matched Ion Counts',
#  'Normalized Spectral Angle',
#  'Localized Scores',
#  'Improvement Possible',
#  'Cumulative Target',
#  'Cumulative Decoy',
#  'QValue',
#  'Cumulative Target Notch',
#  'Cumulative Decoy Notch',
#  'QValue Notch',
#  'PEP',
#  'PEP_QValue',
#  'Species']

# %%
##
## Make a barplot of the detected peptides
##

peptide_df = refseq_df[['Species', 'Base Sequence']].drop_duplicates()
peptide_df = peptide_df.groupby(['Species']).agg(['count'])
peptide_df.columns = peptide_df.columns.droplevel(0)
peptide_df = peptide_df.reset_index()
peptide_df = peptide_df[peptide_df['Species'].isin(['Cow (liver)', 'Fish (lake trout)', 'Human (liver)'])]
print(peptide_df.head())

#colors = pd.DataFrame(
#    {'Species': ['Apple', 'Cow (liver)', 'Fish (lake trout)', 'Human (liver)', 'Peach', 'Rice', 'Tomato'],
#     'color': ['red', 'teal', 'blue', 'peru', 'peach', 'green', 'crimson']}
#)
colors = [['green', 'blue', 'orange']]

#peptide_df = pd.merge(peptide_df, colors, on='Species')

sns.set_style("white")

# Plot peptide detections per gradient length
g = sns.barplot(x='Species', y='count', data=peptide_df, capsize=.1, ci="sd")

#sns.swarmplot(x='Species', y='count', data=peptide_df, color="0", alpha=.5)
g.set_xticklabels(g.get_xticklabels(), fontsize=15, rotation='vertical')
g.set(xlabel='Species', ylabel='unique peptides (1% FDR)')
plt.show()
# Out:
#              Species   count
# 1        Cow (liver)  205075
# 2  Fish (lake trout)   97869
# 3      Human (liver)  133872
# C:\Users\linds\AppData\Local\Temp\ipykernel_8644\2465085231.py:23: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   g = sns.barplot(x='Species', y='count', data=peptide_df, capsize=.1, ci="sd")

# %%
# Alternative barchart that gives specified colors

x_pos = np.arange(len(peptide_df['Species']))

# Create bars with different colors
plt.bar(x_pos, peptide_df['count'], 
        color=['green', 'blue', 'peru'])

# Create names on the x-axis
plt.xticks(x_pos, peptide_df['Species'], rotation = 90)
plt.ylabel('unique peptides (1% FDR)')

# Show graph
plt.show()

# %%
# Venn diagram for human/cow/fish overlaps
# upset plot?
import matplotlib.pyplot as plt
from matplotlib_venn import venn3

plt.figure(edgecolor=None, facecolor=None)
c = venn3([set(refseq_df[refseq_df['Species'] == 'Human (liver)']['Base Sequence']), 
           set(refseq_df[refseq_df['Species'] == 'Cow (liver)']['Base Sequence']), 
           set(refseq_df[refseq_df['Species'] == 'Fish (lake trout)']['Base Sequence'])], 
          ('Human (liver)', 'Cow (liver)', 'Fish (lake trout)'))
c.get_patch_by_id('100').set_color('peru')  # set human color
c.get_patch_by_id('010').set_color('green')  # set cow color
c.get_patch_by_id('001').set_color('blue')  # set fish color
c.get_patch_by_id('100').set_edgecolor('none')
c.get_patch_by_id('010').set_edgecolor('none')
c.get_patch_by_id('001').set_edgecolor('none')
c.get_patch_by_id('100').set_alpha(0.6)
c.get_patch_by_id('010').set_alpha(0.6)
c.get_patch_by_id('001').set_alpha(0.6)
c.get_patch_by_id('110').set_color('magenta')
c.get_patch_by_id('110').set_edgecolor('none')
c.get_patch_by_id('110').set_alpha(0.4)
#c.get_patch_by_id('101').set_color('cyan')
#c.get_patch_by_id('101').set_edgecolor('none')
#c.get_patch_by_id('101').set_alpha(0.4)
#c.get_patch_by_id('011').set_color('pink')
#c.get_patch_by_id('011').set_edgecolor('none')
#c.get_patch_by_id('011').set_alpha(0.4)
for text in c.set_labels:
    text.set_fontsize(20)
for text in c.subset_labels:
    text.set_fontsize(15)

matplotlib.pyplot.savefig('test.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 34
#      31 for text in c.subset_labels:
#      32     text.set_fontsize(15)
# ---> 34 matplotlib.pyplot.savefig('test.png')
#
# NameError: name 'matplotlib' is not defined

# %%
##
## Make a barplot of the detected proteins
## NOTE: this doesn't seem right, there's 60k proteins detected in human liver?? nahhh
## 

protein_df = refseq_df[['Species', 'Protein Accession']].drop_duplicates()
protein_df = protein_df.groupby(['Species']).agg(['count'])
protein_df.columns = protein_df.columns.droplevel(0)
protein_df = protein_df.reset_index()
print(protein_df.head())

x_pos = np.arange(len(peptide_df['Species']))

# Create bars with different colors
plt.bar(x_pos, protein_df['count'], 
        color=['red', 'teal', 'blue', 'peru', 'lightsalmon', 'green', 'darkred'])

# Create names on the x-axis
plt.xticks(x_pos, peptide_df['Species'], rotation = 90)
plt.ylabel('unique proteins')

# Show graph
plt.show()
